# %% [markdown]
# # Janine Par: ALS Clustering Exercise

# %% [markdown]
# ### Load Libraries Needed

# %%
import numpy as np  
import pandas as pd  
import numbers
import matplotlib.pyplot as plt
import warnings
import seaborn as sns
import scipy.stats as ss
warnings.filterwarnings('ignore')

pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)

# %% [markdown]
# ### Load the ALS Data to Dataframe and Analyze dataset

# %%
df_als=pd.read_csv('als_data.csv', index_col=1, encoding='latin-1')

# %%
#Validate the shape

df_als.shape
# Out:
# (2223, 100)

# %%
# Spot check data
df_als.head(5)
# Out:
#    ID  Age_mean  Albumin_max  Albumin_median  Albumin_min  Albumin_range  \
# 0   1        65         57.0            40.5         38.0       0.066202
# 1   2        48         45.0            41.0         39.0       0.010453
# 2   3        38         50.0            47.0         45.0       0.008929
# 3   4        63         47.0            44.0         41.0       0.012111
# 4   5        63         47.0            45.5         42.0       0.008292
#
#    ALSFRS_slope  ALSFRS_Total_max  ALSFRS_Total_median  ALSFRS_Total_min  \
# 0     -0.965608                30                 28.0                22
# 1     -0.921717                37                 33.0                21
# 2     -0.914787                24                 14.0                10
# 3     -0.598361                30                 29.0                24
# 4     -0.444039                32                 27.5                20
#
#    ALSFRS_Total_range  ALT.SGPT._max  ALT.SGPT._median  ALT.SGPT._min  \
# 0            0.021164           24.0              22.0           18.0
# 1            0.028725           25.0              13.0            8.0
# 2            0.025000           25.0              20.0           14.0
# 3            0.014963           62.0              60.0           41.0
# 4            0.020374           38.0              26.5           22.0
#
#    ALT.SGPT._range  AST.SGOT._max  AST.SGOT._median  AST.SGOT._min  \
# 0         0.020906             31              27.5           23.0
# 1         0.029617             31              17.0           14.0
# 2         0.019643             24              19.0           18.0
# 3         0.052369             46              40.0           33.0
# 4         0.026534             35              26.5           20.0
#
#    AST.SGOT._range  Bicarbonate_max  Bicarbonate_median  Bicarbonate_min  \
# 0         0.027875             30.0                28.0             25.0
# 1         0.029617             32.0                28.0             25.0
# 2         0.010714             35.0                29.0             24.0
# 3         0.032419             23.0                20.0             20.0
# 4         0.024876             32.0                28.0             23.0
#
#    Bicarbonate_range  Blood.Urea.Nitrogen..BUN._max  \
# 0           0.017422                         8.0322
# 1           0.012195                         8.3973
# 2           0.019643                         5.4765
# 3           0.007481                         8.0322
# 4           0.014925                         5.1114
#
#    Blood.Urea.Nitrogen..BUN._median  Blood.Urea.Nitrogen..BUN._min  \
# 0                           7.11945                         6.5718
# 1                           4.74630                         4.0161
# 2                           4.38120                         3.6510
# 3                           8.03220                         6.5718
# 4                           4.19865                         3.6510
#
#    Blood.Urea.Nitrogen..BUN._range  bp_diastolic_max  bp_diastolic_median  \
# 0                         0.005089                90                 83.0
# 1                         0.007633                80                 78.0
# 2                         0.003260                86                 76.0
# 3                         0.003642                90                 80.0
# 4                         0.002422               100                 80.0
#
#    bp_diastolic_min  bp_diastolic_range  bp_systolic_max  bp_systolic_median  \
# 0                69            0.055556              160               139.0
# 1                64            0.028725              140               132.5
# 2                58            0.050000              120               110.0
# 3                70            0.049875              150               130.0
# 4                68            0.053068              160               130.0
#
#    bp_systolic_min  bp_systolic_range  Calcium_max  Calcium_median  \
# 0              129           0.082011      2.49500        2.220550
# 1              104           0.064632      2.32035        2.170650
# 2               90           0.053571      2.47005        2.295400
# 3              120           0.074813      2.47005        2.345300
# 4              104           0.092869      2.42015        2.257975
#
#    Calcium_min  Calcium_range  Chloride_max  Chloride_median  Chloride_min  \
# 0      2.22055       0.000956         109.0            108.0         103.0
# 1      2.02095       0.000522         108.0            102.0         100.0
# 2      2.19560       0.000490         108.0            106.0         104.0
# 3      2.23000       0.000474         109.0            107.0         106.0
# 4      2.17065       0.000414         107.0            104.0         100.0
#
#    Chloride_range  Creatinine_max  Creatinine_median  Creatinine_min  \
# 0        0.020906           79.56              79.56           70.72
# 1        0.013937           61.88              53.04           44.20
# 2        0.007143           88.40              79.56           70.72
# 3        0.007481           70.72              61.88           53.04
# 4        0.011609           61.88              48.62           26.52
#
#    Creatinine_range  Gender_mean  Glucose_max  Glucose_median  ...  \
# 0          0.030801            1       7.4370          4.4955  ...
# 1          0.030801            1       6.7710          4.9950  ...
# 2          0.031571            2       5.6610          5.1060  ...
# 3          0.044090            2       5.1060          4.7730  ...
# 4          0.058640            1       7.4925          5.7165  ...
#
#    Glucose_range  hands_max  hands_median  hands_min  hands_range  \
# 0       0.011216          8           7.5          6     0.005291
# 1       0.004738          8           6.0          6     0.003591
# 2       0.002577          4           1.0          0     0.007143
# 3       0.001107          6           5.5          4     0.004988
# 4       0.004050          8           6.5          3     0.008489
#
#    Hematocrit_max  Hematocrit_median  Hematocrit_min  Hematocrit_range  \
# 0            44.6              43.15            40.7          0.013589
# 1            41.9              39.60            37.7          0.007317
# 2            49.1              46.20            44.0          0.009107
# 3            46.3              43.00            41.7          0.011471
# 4            44.0              42.85            39.5          0.007463
#
#    Hemoglobin_max  Hemoglobin_median  Hemoglobin_min  Hemoglobin_range  \
# 0           156.0              146.0           143.0          0.045296
# 1           138.0              132.0           128.0          0.017422
# 2           161.0              154.0           151.0          0.017857
# 3           154.0              145.0           144.0          0.024938
# 4           152.0              146.5           138.0          0.023217
#
#    leg_max  leg_median  leg_min  leg_range  mouth_max  mouth_median  \
# 0        8         6.5        4   0.010582          5           3.5
# 1        8         7.5        3   0.008977          9           8.0
# 2        4         3.0        2   0.003571         10           7.0
# 3        4         3.5        2   0.004988         12          12.0
# 4        2         2.0        0   0.003396         12          12.0
#
#    mouth_min  mouth_range  onset_delta_mean  onset_site_mean  Platelets_max  \
# 0          0     0.013228             -1023                1            172
# 1          4     0.008977              -341                1            286
# 2          4     0.010714             -1181                1            233
# 3         12     0.000000              -365                2            275
# 4         12     0.000000             -1768                2            313
#
#    Platelets_median  Platelets_min  Potassium_max  Potassium_median  \
# 0             169.0          152.0            4.5              4.25
# 1             264.0          230.0            5.0              4.30
# 2             213.0          167.0            4.1              4.00
# 3             233.0          204.0            4.3              4.20
# 4             283.5          268.0            4.6              3.75
#
#    Potassium_min  Potassium_range  pulse_max  pulse_median  pulse_min  \
# 0            4.0         0.001742         79          68.0         61
# 1            3.9         0.001916         90          76.0         64
# 2            3.9         0.000357         82          73.0         60
# 3            4.0         0.000748         84          72.0         68
# 4            3.5         0.001824        101          96.0         74
#
#    pulse_range  respiratory_max  respiratory_median  respiratory_min  \
# 0     0.047619                4                 3.0                3
# 1     0.046679                4                 4.0                3
# 2     0.039286                4                 4.0                4
# 3     0.039900                3                 3.0                3
# 4     0.044776                4                 4.0                3
#
#    respiratory_range  Sodium_max  Sodium_median  Sodium_min  Sodium_range  \
# 0           0.002646       148.0          145.5       143.0      0.017422
# 1           0.001795       142.0          138.0       136.0      0.010453
# 2           0.000000       145.0          143.0       140.0      0.008929
# 3           0.000000       143.0          139.0       138.0      0.012469
# 4           0.001698       143.0          140.0       138.0      0.008292
#
#    SubjectID  trunk_max  trunk_median  trunk_min  trunk_range  Urine.Ph_max  \
# 0        533          8           7.0          7     0.002646           6.0
# 1        649          8           7.0          5     0.005386           7.0
# 2       1234          5           0.0          0     0.008929           6.0
# 3       2492          5           5.0          3     0.004988           7.0
# 4       2956          6           4.0          1     0.008489           6.0
#
#    Urine.Ph_median  Urine.Ph_min
# 0              6.0           6.0
# 1              5.0           5.0
# 2              5.0           5.0
# 3              6.0           5.0
# 4              5.0           5.0
#
# [5 rows x 101 columns]

# %%
#Check null values 
df_als.isna().sum().any()
# Out:
# False

# %% [markdown]
#  Identify categorical and numeric variables

# %%
cat_var = df_als.select_dtypes(exclude=np.number)
nume_var = df_als.select_dtypes(include=np.number)
nume_var.head ()
# Out:
#    ID  Age_mean  Albumin_max  Albumin_median  Albumin_min  Albumin_range  \
# 0   1        65         57.0            40.5         38.0       0.066202
# 1   2        48         45.0            41.0         39.0       0.010453
# 2   3        38         50.0            47.0         45.0       0.008929
# 3   4        63         47.0            44.0         41.0       0.012111
# 4   5        63         47.0            45.5         42.0       0.008292
#
#    ALSFRS_slope  ALSFRS_Total_max  ALSFRS_Total_median  ALSFRS_Total_min  \
# 0     -0.965608                30                 28.0                22
# 1     -0.921717                37                 33.0                21
# 2     -0.914787                24                 14.0                10
# 3     -0.598361                30                 29.0                24
# 4     -0.444039                32                 27.5                20
#
#    ALSFRS_Total_range  ALT.SGPT._max  ALT.SGPT._median  ALT.SGPT._min  \
# 0            0.021164           24.0              22.0           18.0
# 1            0.028725           25.0              13.0            8.0
# 2            0.025000           25.0              20.0           14.0
# 3            0.014963           62.0              60.0           41.0
# 4            0.020374           38.0              26.5           22.0
#
#    ALT.SGPT._range  AST.SGOT._max  AST.SGOT._median  AST.SGOT._min  \
# 0         0.020906             31              27.5           23.0
# 1         0.029617             31              17.0           14.0
# 2         0.019643             24              19.0           18.0
# 3         0.052369             46              40.0           33.0
# 4         0.026534             35              26.5           20.0
#
#    AST.SGOT._range  Bicarbonate_max  Bicarbonate_median  Bicarbonate_min  \
# 0         0.027875             30.0                28.0             25.0
# 1         0.029617             32.0                28.0             25.0
# 2         0.010714             35.0                29.0             24.0
# 3         0.032419             23.0                20.0             20.0
# 4         0.024876             32.0                28.0             23.0
#
#    Bicarbonate_range  Blood.Urea.Nitrogen..BUN._max  \
# 0           0.017422                         8.0322
# 1           0.012195                         8.3973
# 2           0.019643                         5.4765
# 3           0.007481                         8.0322
# 4           0.014925                         5.1114
#
#    Blood.Urea.Nitrogen..BUN._median  Blood.Urea.Nitrogen..BUN._min  \
# 0                           7.11945                         6.5718
# 1                           4.74630                         4.0161
# 2                           4.38120                         3.6510
# 3                           8.03220                         6.5718
# 4                           4.19865                         3.6510
#
#    Blood.Urea.Nitrogen..BUN._range  bp_diastolic_max  bp_diastolic_median  \
# 0                         0.005089                90                 83.0
# 1                         0.007633                80                 78.0
# 2                         0.003260                86                 76.0
# 3                         0.003642                90                 80.0
# 4                         0.002422               100                 80.0
#
#    bp_diastolic_min  bp_diastolic_range  bp_systolic_max  bp_systolic_median  \
# 0                69            0.055556              160               139.0
# 1                64            0.028725              140               132.5
# 2                58            0.050000              120               110.0
# 3                70            0.049875              150               130.0
# 4                68            0.053068              160               130.0
#
#    bp_systolic_min  bp_systolic_range  Calcium_max  Calcium_median  \
# 0              129           0.082011      2.49500        2.220550
# 1              104           0.064632      2.32035        2.170650
# 2               90           0.053571      2.47005        2.295400
# 3              120           0.074813      2.47005        2.345300
# 4              104           0.092869      2.42015        2.257975
#
#    Calcium_min  Calcium_range  Chloride_max  Chloride_median  Chloride_min  \
# 0      2.22055       0.000956         109.0            108.0         103.0
# 1      2.02095       0.000522         108.0            102.0         100.0
# 2      2.19560       0.000490         108.0            106.0         104.0
# 3      2.23000       0.000474         109.0            107.0         106.0
# 4      2.17065       0.000414         107.0            104.0         100.0
#
#    Chloride_range  Creatinine_max  Creatinine_median  Creatinine_min  \
# 0        0.020906           79.56              79.56           70.72
# 1        0.013937           61.88              53.04           44.20
# 2        0.007143           88.40              79.56           70.72
# 3        0.007481           70.72              61.88           53.04
# 4        0.011609           61.88              48.62           26.52
#
#    Creatinine_range  Gender_mean  Glucose_max  Glucose_median  ...  \
# 0          0.030801            1       7.4370          4.4955  ...
# 1          0.030801            1       6.7710          4.9950  ...
# 2          0.031571            2       5.6610          5.1060  ...
# 3          0.044090            2       5.1060          4.7730  ...
# 4          0.058640            1       7.4925          5.7165  ...
#
#    Glucose_range  hands_max  hands_median  hands_min  hands_range  \
# 0       0.011216          8           7.5          6     0.005291
# 1       0.004738          8           6.0          6     0.003591
# 2       0.002577          4           1.0          0     0.007143
# 3       0.001107          6           5.5          4     0.004988
# 4       0.004050          8           6.5          3     0.008489
#
#    Hematocrit_max  Hematocrit_median  Hematocrit_min  Hematocrit_range  \
# 0            44.6              43.15            40.7          0.013589
# 1            41.9              39.60            37.7          0.007317
# 2            49.1              46.20            44.0          0.009107
# 3            46.3              43.00            41.7          0.011471
# 4            44.0              42.85            39.5          0.007463
#
#    Hemoglobin_max  Hemoglobin_median  Hemoglobin_min  Hemoglobin_range  \
# 0           156.0              146.0           143.0          0.045296
# 1           138.0              132.0           128.0          0.017422
# 2           161.0              154.0           151.0          0.017857
# 3           154.0              145.0           144.0          0.024938
# 4           152.0              146.5           138.0          0.023217
#
#    leg_max  leg_median  leg_min  leg_range  mouth_max  mouth_median  \
# 0        8         6.5        4   0.010582          5           3.5
# 1        8         7.5        3   0.008977          9           8.0
# 2        4         3.0        2   0.003571         10           7.0
# 3        4         3.5        2   0.004988         12          12.0
# 4        2         2.0        0   0.003396         12          12.0
#
#    mouth_min  mouth_range  onset_delta_mean  onset_site_mean  Platelets_max  \
# 0          0     0.013228             -1023                1            172
# 1          4     0.008977              -341                1            286
# 2          4     0.010714             -1181                1            233
# 3         12     0.000000              -365                2            275
# 4         12     0.000000             -1768                2            313
#
#    Platelets_median  Platelets_min  Potassium_max  Potassium_median  \
# 0             169.0          152.0            4.5              4.25
# 1             264.0          230.0            5.0              4.30
# 2             213.0          167.0            4.1              4.00
# 3             233.0          204.0            4.3              4.20
# 4             283.5          268.0            4.6              3.75
#
#    Potassium_min  Potassium_range  pulse_max  pulse_median  pulse_min  \
# 0            4.0         0.001742         79          68.0         61
# 1            3.9         0.001916         90          76.0         64
# 2            3.9         0.000357         82          73.0         60
# 3            4.0         0.000748         84          72.0         68
# 4            3.5         0.001824        101          96.0         74
#
#    pulse_range  respiratory_max  respiratory_median  respiratory_min  \
# 0     0.047619                4                 3.0                3
# 1     0.046679                4                 4.0                3
# 2     0.039286                4                 4.0                4
# 3     0.039900                3                 3.0                3
# 4     0.044776                4                 4.0                3
#
#    respiratory_range  Sodium_max  Sodium_median  Sodium_min  Sodium_range  \
# 0           0.002646       148.0          145.5       143.0      0.017422
# 1           0.001795       142.0          138.0       136.0      0.010453
# 2           0.000000       145.0          143.0       140.0      0.008929
# 3           0.000000       143.0          139.0       138.0      0.012469
# 4           0.001698       143.0          140.0       138.0      0.008292
#
#    SubjectID  trunk_max  trunk_median  trunk_min  trunk_range  Urine.Ph_max  \
# 0        533          8           7.0          7     0.002646           6.0
# 1        649          8           7.0          5     0.005386           7.0
# 2       1234          5           0.0          0     0.008929           6.0
# 3       2492          5           5.0          3     0.004988           7.0
# 4       2956          6           4.0          1     0.008489           6.0
#
#    Urine.Ph_median  Urine.Ph_min
# 0              6.0           6.0
# 1              5.0           5.0
# 2              5.0           5.0
# 3              6.0           5.0
# 4              5.0           5.0
#
# [5 rows x 101 columns]

# %%
categorical.head ()
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %% [markdown]
# # 1. Remove any data that is not relevant to the patient’s ALS condition.

# %% [markdown]
# Dropping ID and Subject ID since they are features that will not impact the model

# %%
df_als.drop(columns = ['ID', 'SubjectID'], inplace = True)
df_als.shape
# Out:
# (2223, 99)

# %% [markdown]
# Feature reduction by removing the highest correlated data elements using .90 as threshold which have removed 4 features.
# Correlated variables may increase the weight of the clusters that they belong to, and make them more distinct from other clusters. This may introduce bias if correlation is irrelevant.

# %%
import numpy as np

# Create correlation matrix
corr_matrix = df_als.corr().abs()

# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))

# Find features with correlation greater than 0.95
to_drop = [column for column in upper.columns if any(upper[column] > 0.90)]

# Drop features 
to_drop
df_als.drop(to_drop, axis=1, inplace=True)

# %%
df_als.shape
# Out:
# (2223, 95)

# %% [markdown]
# # 2. Apply a standard scalar to the data.
# This class implements a type of feature scaling called standardization. Standardization scales, or shifts, the values for each numerical feature in your dataset so that the features have a mean of 0 and standard deviation of 1:

# %%
from sklearn import preprocessing

# %%
scaler = preprocessing.StandardScaler()
scaled_feature = scaler.fit_transform(df_als.values)

# %% [markdown]
# Validate Data

# %%
df_als_scaled = pd.DataFrame(scaled_feature, index=df_als.index, columns=df_als.columns)
df_als_scaled.head()
# Out:
#    Age_mean  Albumin_max  Albumin_median  Albumin_min  Albumin_range  \
# 0  0.917137     3.089417       -1.300781    -0.866550       5.480929
# 1 -0.574879    -0.622016       -1.112401    -0.553303      -0.347725
# 2 -1.452535     0.924415        1.148162     1.326179      -0.507103
# 3  0.741606    -0.003443        0.017880     0.073191      -0.174361
# 4  0.741606    -0.003443        0.583021     0.386438      -0.573670
#
#    ALSFRS_slope  ALSFRS_Total_max  ALSFRS_Total_median  ALSFRS_Total_min  \
# 0     -0.381450         -0.318520             0.134960          0.247368
# 1     -0.310907          0.998995             0.888863          0.130839
# 2     -0.299769         -1.447819            -1.975969         -1.150976
# 3      0.208801         -0.318520             0.285741          0.480425
# 4      0.456831          0.057913             0.059570          0.014311
#
#    ALSFRS_Total_range  ALT.SGPT._max  ALT.SGPT._median  ALT.SGPT._min  \
# 0           -0.301588      -0.679085         -0.704767      -0.446606
# 1            0.166537      -0.656774         -1.281749      -1.337181
# 2           -0.064100      -0.656774         -0.832985      -0.802836
# 3           -0.685524       0.168760          1.731378       1.601718
# 4           -0.350529      -0.366721         -0.416276      -0.090376
#
#    ALT.SGPT._range  AST.SGOT._max  AST.SGOT._median  AST.SGOT._min  \
# 0        -0.453087      -0.343750         -0.164404       0.197134
# 1        -0.374515      -0.343750         -1.259094      -1.020129
# 2        -0.464480      -0.542158         -1.050582      -0.479123
# 3        -0.169287       0.081411          1.138799       1.549648
# 4        -0.402321      -0.230374         -0.268660      -0.208621
#
#    AST.SGOT._range  Bicarbonate_max  Bicarbonate_median  Bicarbonate_min  \
# 0        -0.253516        -0.283619            0.471374         0.762330
# 1        -0.232796         0.348541            0.471374         0.762330
# 2        -0.457607         1.296780            0.926265         0.347043
# 3        -0.199469        -2.496176           -3.167753        -1.314102
# 4        -0.289183         0.348541            0.471374        -0.068243
#
#    Bicarbonate_range  Blood.Urea.Nitrogen..BUN._max  \
# 0           0.049077                       0.292860
# 1          -0.414378                       0.450297
# 2           0.246046                      -0.809203
# 3          -0.832374                       0.292860
# 4          -0.172274                      -0.966640
#
#    Blood.Urea.Nitrogen..BUN._median  Blood.Urea.Nitrogen..BUN._min  \
# 0                          1.169674                       1.780659
# 1                         -0.608052                      -0.106928
# 2                         -0.881549                      -0.376583
# 3                          1.853414                       1.780659
# 4                         -1.018297                      -0.376583
#
#    Blood.Urea.Nitrogen..BUN._range  bp_diastolic_max  bp_diastolic_median  \
# 0                        -0.403233         -0.231902             0.260444
# 1                         0.098656         -1.373942            -0.429788
# 2                        -0.763966         -0.688718            -0.705880
# 3                        -0.688597         -0.231902            -0.153695
# 4                        -0.929260          0.910139            -0.153695
#
#    bp_diastolic_min  bp_diastolic_range  bp_systolic_max  bp_systolic_median  \
# 0         -0.105510            0.289532         0.816774            0.774854
# 1         -0.697803           -0.694129        -0.453027            0.240235
# 2         -1.408555            0.085852        -1.722828           -1.610367
# 3          0.012949            0.081281         0.181873            0.034613
# 4         -0.223968            0.198332         0.816774            0.034613
#
#    bp_systolic_min  bp_systolic_range  Calcium_max  Calcium_median  \
# 0         1.391144           0.327228     0.111898       -1.414439
# 1        -0.842491          -0.197758    -0.857276       -1.978932
# 2        -2.093327          -0.531883    -0.026555       -0.567701
# 3         0.587035           0.109797    -0.026555       -0.003208
# 4        -0.842491           0.655247    -0.303462       -0.991070
#
#    Calcium_min  Calcium_range  Chloride_max  Chloride_median  Chloride_min  \
# 0    -0.013342       0.863965      0.706250         1.938377      1.084444
# 1    -1.168779      -0.039684      0.324043        -0.631202      0.213635
# 2    -0.157771      -0.105200      0.324043         1.081851      1.374714
# 3     0.041362      -0.138785      0.706250         1.510114      1.955254
# 4    -0.302201      -0.263872     -0.058165         0.225325      0.213635
#
#    Chloride_range  Creatinine_max  Creatinine_median  Creatinine_min  \
# 0        0.260030        0.039923           0.827718        1.015944
# 1       -0.336277       -0.862670          -0.700245       -0.421909
# 2       -0.917676        0.491219           0.827718        1.015944
# 3       -0.888715       -0.411374          -0.190924        0.057375
# 4       -0.535540       -0.862670          -0.954905       -1.380478
#
#    Creatinine_range  Gender_mean  Glucose_max  Glucose_median  Glucose_min  \
# 0         -0.733335    -1.325920     0.109146       -0.797426    -0.037997
# 1         -0.733335    -1.325920    -0.153752       -0.395743    -0.172186
# 2         -0.712887     0.754193    -0.591917       -0.306480    -0.037997
# 3         -0.380457     0.754193    -0.810999       -0.574268     0.319841
# 4          0.005933    -1.325920     0.131055        0.184466     0.632950
#
#    Glucose_range  hands_max  hands_median  hands_min  hands_range  \
# 0       0.789353   0.919974      1.054904   1.132573    -0.335338
# 1      -0.254893   0.919974      0.445034   1.132573    -0.693562
# 2      -0.603234  -1.103377     -1.587866  -1.168807     0.054805
# 3      -0.840117  -0.091702      0.241744   0.365446    -0.399273
# 4      -0.365802   0.919974      0.648324  -0.018117     0.338399
#
#    Hematocrit_max  Hematocrit_range  Hemoglobin_max  Hemoglobin_median  \
# 0        0.205759          0.191746        0.303416           0.147495
# 1       -0.003054         -0.365664       -1.111871          -1.059377
# 2        0.553779         -0.206570        0.696552           0.837136
# 3        0.337233          0.003549        0.146162           0.061290
# 4        0.159356         -0.352722       -0.011092           0.190598
#
#    Hemoglobin_min  Hemoglobin_range   leg_max  leg_median   leg_min  \
# 0        0.506397          0.200822  1.198700    1.074563  0.709255
# 1       -0.501175         -0.592730  1.198700    1.513108  0.238466
# 2        1.043769         -0.580331 -0.583715   -0.460344 -0.232324
# 3        0.573569         -0.378758 -0.583715   -0.241072 -0.232324
# 4        0.170540         -0.427736 -1.474923   -0.898889 -1.173903
#
#    leg_range  mouth_max  mouth_min  mouth_range  onset_delta_mean  \
# 0   1.011076  -3.027367  -2.080167     1.082677         -0.825839
# 1   0.643794  -0.918857  -1.010429     0.388826          0.830675
# 2  -0.592848  -0.391730  -1.010429     0.672452         -1.209607
# 3  -0.268864   0.662526   1.129048    -1.076402          0.772382
# 4  -0.633079   0.662526   1.129048    -1.076402         -2.635375
#
#    onset_site_mean  Platelets_max  Platelets_median  Potassium_max  \
# 0        -1.909933      -1.614917         -1.326277      -0.096872
# 1        -1.909933       0.009951          0.479304       0.280454
# 2        -1.909933      -0.745470         -0.490008      -0.398733
# 3         0.475337      -0.146835         -0.109886      -0.247803
# 4         0.475337       0.394788          0.849923      -0.021407
#
#    Potassium_median  Potassium_min  Potassium_range  pulse_max  pulse_median  \
# 0          0.249901       0.542515        -0.000570  -1.048639     -1.063702
# 1          0.455645       0.162274         0.059556  -0.057859     -0.115369
# 2         -0.778819       0.162274        -0.478576  -0.778426     -0.470994
# 3          0.044157       0.542515        -0.343636  -0.598285     -0.589536
# 4         -1.807538      -1.358691         0.027748   0.932920      2.255465
#
#    pulse_min  pulse_range  respiratory_max  respiratory_median  \
# 0  -0.563513    -0.217842         0.301454           -0.968019
# 1  -0.177000    -0.252168         0.301454            0.665307
# 2  -0.692351    -0.522019         0.301454            0.665307
# 3   0.338351    -0.499588        -3.049205           -0.968019
# 4   1.111378    -0.321613         0.301454            0.665307
#
#    respiratory_min  respiratory_range  Sodium_max  Sodium_median  Sodium_min  \
# 0         0.197810           0.053311    1.959640       2.992342    2.300470
# 1         0.197810          -0.289979   -0.612561      -1.198812   -0.278144
# 2         1.145505          -1.014914    0.673540       1.595291    1.195350
# 3         0.197810          -1.014914   -0.183861      -0.639992    0.458603
# 4         0.197810          -0.329364   -0.183861      -0.081171    0.458603
#
#    Sodium_range  trunk_max  trunk_median  trunk_min  trunk_range  \
# 0      0.260968   1.028018      0.981832   1.715365    -0.997420
# 1     -0.489913   1.028018      0.981832   0.867032    -0.388669
# 2     -0.654169  -0.688950     -2.280669  -1.253800     0.398249
# 3     -0.272701  -0.688950      0.049689   0.018699    -0.477181
# 4     -0.722774  -0.116627     -0.416383  -0.829634     0.300598
#
#    Urine.Ph_max  Urine.Ph_median  Urine.Ph_min
# 0     -0.880376         0.463054      1.868532
# 1      0.192665        -1.137208     -0.419151
# 2     -0.880376        -1.137208     -0.419151
# 3      0.192665         0.463054     -0.419151
# 4     -0.880376        -1.137208     -0.419151

# %% [markdown]
# # 3. Create a plot of the cluster silhouette score versus the number of clusters in a K-means cluster.

# %%
from sklearn.cluster import KMeans, SpectralClustering
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_samples, silhouette_score
from sklearn.decomposition import PCA

# %% [markdown]
# This loops through values of k (2-15)  and compute the silhouette coefficient:

# %%
range_n_clusters = list(range(2, 15))
silhouette_avg = []
for num_clusters in range_n_clusters:
 
 # initialise kmeans
 kmeans = KMeans(n_clusters=num_clusters)
 kmeans.fit(scaled_feature)
 cluster_labels = kmeans.labels_
 
 # silhouette score df_als_scaled features
 silhouette_avg.append(silhouette_score(scaled_feature, cluster_labels))

# %%
plt.plot(range_n_clusters,silhouette_avg,'bx-')
plt.xlabel('Values of K') 
plt.ylabel('Silhouette score') 
plt.title('Silhouette analysis For Optimal k')
plt.show()

# %% [markdown]
# # 4. Use the plot created in (3) to choose on optimal number of clusters for K-means. Justify your choice.
#
#
#  Plotting the average silhouette scores for each k shows that the best choice for <b>  k is 2 </b>  since it has the highest silhouette score:
#
#
# # 5. Fit a K-means model to the data with the optimal number of clusters chosen in part (4).

# %% [markdown]
# The Red and Blue clusters below seem to have overlap and the not clearly separated even when using the k = 2

# %%
Kmeans = KMeans(n_clusters = 2,                 # Set to optimal cluster =2 
                init = 'k-means++',             # Initialization 
                max_iter = 300,                 # Maximum num of iterations
                n_init = 10,                    #  how often algorithm will run with different centroid
                random_state = 0)               # Random state for reproducibility

y_Kmeans = Kmeans.fit_predict(scaled_feature)

plt.figure(figsize = (20,10))

#Plot the clusters and centroids
plt.scatter(scaled_feature[y_Kmeans == 0, 0], 
            scaled_feature[y_Kmeans == 0, 1], 
            s = 200, c = 'red', label = 'Cluster1')
plt.scatter(scaled_feature[y_Kmeans == 1, 0],
            scaled_feature[y_Kmeans == 1, 1], 
            s = 200, c = 'blue', label = 'Cluster2')

plt.scatter(Kmeans.cluster_centers_[:, 0], Kmeans.cluster_centers_[:, 1], 
            s=400,                             
            c='yellow',
            label = 'Centroid',
            marker = "*")                         

plt.legend()
plt.show()

# %%
score = silhouette_score(scaled_feature, y_Kmeans, metric='euclidean')
print(score)
# Out:
# 0.08140640561048122

# %% [markdown]
# # 6. Fit a PCA transformation with two features to the scaled data.
#
# Perform PCA with the chosen number of components=2

# %%
scaled_pca = PCA(n_components=2).fit(df_als_scaled.values)
scaled_pca_feature = scaled_pca.transform(df_als_scaled.values)

# %%
scaled_pca_feature
# Out:
# array([[-1.81655218,  1.46123084],
#        [-1.71149995, -1.25982109],
#        [ 1.56352824, -3.55430833],
#        ...,
#        [-0.26677335, -0.04996746],
#        [-0.11164215,  1.47319157],
#        [ 1.28715739,  4.26045586]])

# %% [markdown]
# # 7. Make a scatterplot the PCA transformed data coloring each point by its cluster value.

# %% [markdown]
# Red and Blue clusters are clearly separated when using PCA Transformed Data

# %%
Kmeans = KMeans(n_clusters = 2,                 # Set amount of clusters
                init = 'k-means++',             # Initialization 
                max_iter = 300,                 # Maximum num of iterations
                n_init = 10,                    #  how often algorithm will run with different centroid
                random_state = 0)               # Random state for reproducibility

y_Kmeans = Kmeans.fit_predict(scaled_pca_feature)

plt.figure(figsize = (20,10))

#PLot the clusters and centroid
plt.scatter(scaled_pca_feature[y_Kmeans == 0, 0], 
            scaled_pca_feature[y_Kmeans == 0, 1], 
            s = 200, c = 'red', label = 'Cluster1')
plt.scatter(scaled_pca_feature[y_Kmeans == 1, 0], 
            scaled_pca_feature[y_Kmeans == 1, 1], 
            s = 200, c = 'blue', label = 'Cluster2')

plt.scatter(Kmeans.cluster_centers_[:, 0], Kmeans.cluster_centers_[:, 1], 
            s=400,                             
            c='yellow',
            label = 'Centroid',
            marker = "*")                         

plt.legend()
plt.show()

# %%
score = silhouette_score(scaled_feature, y_Kmeans, metric='euclidean')
print(score)
# Out:
# 0.08218190537708846

# %% [markdown]
# # 9. Summary and Conclusion.

# %% [markdown]
# In this K-means clustering exercise on ALS dataset, Here are my findings:
#
# * Standard scaling is important as we want to treat all the features equally and we can achieve this by transforming the features to a values that fall within the same numerical range.
#
#
# * Based on the silhouette v.s number of clusters for <b> Standard Scaled ALS dataset</b> , the best choice for <b> K = 2 </b>  because it shows the highest silhouette score. However, I still observed that there are overlap between two clusters. The blue and red segment are not that clearly separated even after reducing a few highly correlated features.
#
#
# * After fitting the <b> scaled dataset to PCA (with 2 features) and runnig it to K-means (n_cluster=2) </b> , the Red and Blue segments are clearly separated which means that PCA has reduced the noise and redundancy in the data and shows a more improved quality of the clusters.
